# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def welcomeMessage(name,department):

    msgbox.showinfo("Info","Welcome to GIG LOGISTICS")
    # Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {name} | {department}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This is Python GUI with Tkinter")
    label_2.pack()

    # Run the Tkinter event loop
    root.mainloop()

def submit():
    names = names_entry.get()
    department = department_entry.get()

    names = ["Adeniran Oluwatamilore","Adewumi Ayomide","Adoh-Ajagbe Oshim","Agbakuru-\Nwogu Chukwunonye","Agbakwuru Chiemeziem","Akinde Oluwatimehin","Arnika Osose","Atelly Daniel","Azogbu Onyekachi","Beture Shalom","Chukwuma Shalom","Ebi Stephanie","Egboro Jason","Ejedimu Edward","Eleri Otu","Eze Onyinyechi","Ezeonye Makuochukwu","Giwa Moyosore","Icha Ayonete","Ikpati Eche","Iloenyos Michael","Iyawe Oluwadamilola","Nwokolo Chijindu","Nwotoki Joseph","Ogbasogie Daisy","Obi Samuel","Obialor Betha","Ogbonna Blues tide","Ogbonna Mary","Okoacha-Ojeah Raphael","Okolo Victor","Okoro Derek","Olowoke Akorede","Olubuad Rasheed","Osemeke Daniel","Ossai Mary-Cynthia","Peter Owoede","Quadri Oluwafiku","Ude-Ibe Uchenna","Umeh Ejike"]
    Department = ["Logistics","Accounting","Delivery","Accounting","Logistics","Accounting","Logistics","Delivery","Delivery","Delivery","Logistics","Accounting","Administration","Delivery","Administration","Administration","Logistics","Logistics","Accounting","Accounting","Delivery","Delivery","Logistics","Logistics","Accounting","Accounting","Accounting","Delivery","Delivery","Administration","Administration","Logistics","Accounting","Accounting","Accounting","Logistics","Logistics","Delivery","Delivery","Administration"]

    for i in range(40): 

    if name == names[i] and department == department[i] :
        welcomeMessage(username)
    else:
        messagebox.showerror("Login", "ERROR! The Name or Department that you entered does not exist")

root = tk.Tk()
root.title("Login Form")
root.geometry("500x200")


# Create username label and entry
name_label = tk.Label(root, text="Name:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create password label and entry
department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root, show="*")
department_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command= submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
