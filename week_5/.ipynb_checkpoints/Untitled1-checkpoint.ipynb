# %%
import array as arr
def computer_science():
    print("Candidates must have at least credits or a score above 49 in the following subjects listed below:
    print("1.) MATHS")
    print("2.) ENGLISH")
    print("3.) BIOLOGY")
    print("4.) CHEMISTRY")
    print("5.) PHYSICS ")

    name = input("Enter your name:")
    age = int(input("Enter your age:"))
    examination_number = input("Enter your Examination Number:")  
    jamb_score = float(input("Enter Your Jamb Score:"))
    maths_score = float(input("Enter Your Maths Score:"))
    english_score = float(input("Enter Your English Score:"))
    biology_score = float(input("Enter Your Biology Score:"))
    chemistry_score = float(input("Enter Your Chemistry Score:"))
    physics_score = float(input("Enter Your Physics Score:"))
    data_processing = float(input("Enter Your Data Processing Score:"))
    civic_score = float(input("Enter Your Civic Education Score:"))
    further_maths = float(input("Enter Your Further Mathematics Score:"))
    technical_drawing = float(input("Enter your Technical Drawing score:"))
    interview_status = input("Did you pass your interview?")

    if jamb_score >= 250 and maths_score >= 50 and english_score >= 50 and biology_score >= 50 and chemistry_score >= 50 and physics_score >= 50 and interview_status == "yes":
        admitted = arr.array(i, [name,age,examination_number,jamb_score,maths_score,english_score,biology_score,chemistry_score,physics_score,data_processing,civic_score,further_maths,technical_drawing])
        print("Congratulations {name}, you have been admitted into the Computer Science department! Good job )
        print(admitted)
    else:
        not_admitted = arr.array(i, [name,age,examination_number,jamb_score,maths_score,english_score,biology_score,chemistry_score,physics_score,data_processing,civic_score,further_maths,technical_drawing])
        print("You are not admitted, thanks for considering us.")
        print(not_admitted)

def mass_communication():
    print("Candidates must have at least credits or a score above 49 in the following subjects listed below:
    print("1.) MATHS")
    print("2.) ENGLISH")
    print("3.) BIOLOGY")
    print("4.) CHEMISTRY")
    print("5.) PHYSICS ")

    name = input("Enter your name:")
    age = int(input("Enter your age:"))
    examination_number = input("Enter your Examination Number:")  
    jamb_score = float(input("Enter Your Jamb Score:"))
    maths_score = float(input("Enter Your Maths Score:"))
    english_score = float(input("Enter Your English Score:"))
    civic_score = float(input("Enter Your Civic Score:"))
    government_score = float(input("Enter Your Government Score:"))
    economics_score = float(input("Enter Your Economics Score:"))
    agric_science = float(input("Enter Your Agricultural Science Score:"))
    literature_score = float(input("Enter Your Literature Score:"))
    marketing_score = float(input("Enter Your Marketing Score:"))
    commerce_score = float(input("Enter your Commerce score:"))
    interview_status = input("Did you pass your interview?")

    if jamb_score >= 230 and maths_score >= 50 and english_score >= 50 and biology_score >= 50 and chemistry_score >= 50 and physics_score >= 50 and interview_status == "yes":
        admitted = arr.array(i, [name,age,examination_number,jamb_score,maths_score,english_score,civic_score,government_score,economics_score,agric_science,literature_score,marketing_score,commerce_score])
        print("Congratulations {name}, you have been admitted into the Mass Communication Department! Good job )
        print(admitted)
    else:
        not_admitted = arr.array(i, [name,age,examination_number,jamb_score,maths_score,english_score,civic_score,government_score,economics_score,agric_science,literature_score,marketing_score,commerce_score])
        print("You are not admitted, thanks for considering us.")
        print(not_admitted)

def course():
    _applied_course = input("What department do you belong to?")
    if _applied_course == "computer science" :
        computer_science()

    elif _applied_course == "mass_communication" :
        mass_communication()

    else :
        print("The Department you entered is not within our scope of interest")
