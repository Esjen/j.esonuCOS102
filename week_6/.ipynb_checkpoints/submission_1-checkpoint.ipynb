# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

# Dictionary containing menu items and their prices
menu_prices = {
    "jollof rice": 350,
    "coconut fried rice": 350,
    "jollof spaghetti": 350,
    "savory beans": 350,
    "roasted sweet potatoes": 300,
    "fried plantains": 150,
    "mixed vegetable salad": 150,
    "boiled yam": 150,
    "eba": 100,
    "poundo yam": 100,
    "semo": 100,
    "atama soup": 450,
    "egusi soup": 480,
    "sweet chili chicken": 1100,
    "grilled chicken wings": 400,
    "fried beef": 400,
    "fried fish": 500,
    "boiled egg": 200,
    "sauteed sausages": 200,
    "water": 200,
    "glass drink(35cl)": 150,
    "pet drink(35cl)": 300,
    "pet drink(50cl)": 350,
    "glass/canned meat": 500,
    "fresh yo": 600,
    "pineapple juice": 350,
    "mango juice": 350,
    "zobo drink": 350
}


def menu_display():
    window = tk.Toplevel()
    window.title("Welcome to the PAU Cafeteria!")
    window.geometry("900x800")

    # Menu Section
    label_1 = tk.Label(window, text="MENU", font="times 28 bold")
    label_1.grid(row=0, column=0, sticky="ne")

    # RICE/PASTA
    label_2 = tk.Label(window, text="RICE/PASTA", font="times 28 bold")
    label_2.grid(row=1, column=0, sticky="w")

    label_3 = tk.Label(window, text="Jollof Rice       N350", font="times 18")
    label_3.grid(row=2, column=0, sticky="w")

    label_4 = tk.Label(window, text="Coconut Fried Rice       N350", font="times 18")
    label_4.grid(row=3, column=0, sticky="w")

    label_5 = tk.Label(window, text="Jollof Spaghetti       N350", font="times 18")
    label_5.grid(row=4, column=0, sticky="w")

    # SIDE DISHES
    label_6 = tk.Label(window, text="SIDE DISHES", font="times 28 bold")
    label_6.grid(row=5, column=0, sticky="w")

    label_7 = tk.Label(window, text="Savory Beans       N350", font="times 18")
    label_7.grid(row=6, column=0, sticky="w")
    
    label_8 = tk.Label(window, text="Roasted Sweet Potatoes       N300", font="times 18")
    label_8.grid(row=7, column=0, sticky="w")

    label_9 = tk.Label(window, text="Fried Plantains       N150", font="times 18")
    label_9.grid(row=8, column=0, sticky="w")

    label_10 = tk.Label(window, text="Mixed Vegetable Salad       N150", font="times 18")
    label_10.grid(row=9, column=0, sticky="w")

    label_11 = tk.Label(window, text="Boiled Yam       N150", font="times 18")
    label_11.grid(row=10, column=0, sticky="w")

    # SOUPS & SWALLOWS
    label_12 = tk.Label(window, text="SOUPS & SWALLOWS", font="times 28 bold")
    label_12.grid(row=11, column=0, sticky="w")

    label_13 = tk.Label(window, text="Eba       N100", font="times 18")
    label_13.grid(row=12, column=0, sticky="w")

    label_14 = tk.Label(window, text="Poundo Yam      N100", font="times 18")
    label_14.grid(row=13, column=0, sticky="w")

    label_15 = tk.Label(window, text="Semo       N100", font="times 18")
    label_15.grid(row=14, column=0, sticky="w")

    label_16 = tk.Label(window, text="Atama Soup       N450", font="times 18")
    label_16.grid(row=15, column=0, sticky="w")

    label_17 = tk.Label(window, text="Egusi Soup       N480", font="times 18")
    label_17.grid(row=16, column=0, sticky="w")

    # PROTEINS
    label_18 = tk.Label(window, text="PROTEINS", font="times 28 bold")
    label_18.grid(row=1, column=1, sticky="e")

    label_19 = tk.Label(window, text="Sweet Chili Chicken       N1100", font="times 18")
    label_19.grid(row=2, column=1, sticky="e")

    label_20 = tk.Label(window, text="Grilled Chicken Wings       N400", font="times 18")
    label_20.grid(row=3, column=1, sticky="e")

    label_21 = tk.Label(window, text="Fried Beef       N400", font="times 18")
    label_21.grid(row=4, column=1, sticky="e")

    label_22 = tk.Label(window, text="Fried Fish       N500", font="times 18")
    label_22.grid(row=5, column=1, sticky="e")

    label_23 = tk.Label(window, text="Boiled Egg       N200", font="times 18")
    label_23.grid(row=6, column=1, sticky="e")

    label_24 = tk.Label(window, text="Sauteed Sausages       N200", font="times 18")
    label_24.grid(row=7, column=1, sticky="e")

    # BEVERAGES
    label_25 = tk.Label(window, text="BEVERAGES", font="times 28 bold")
    label_25.grid(row=8, column=1, sticky="e")

    label_26 = tk.Label(window, text="Water       N200", font="times 18")
    label_26.grid(row=9, column=1, sticky="e")

    label_27 = tk.Label(window, text="Glass Drink(35cl)       N150", font="times 18")
    label_27.grid(row=10, column=1, sticky="e")

    label_28 = tk.Label(window, text="PET Drink(35cl)       N300", font="times 18")
    label_28.grid(row=11, column=1, sticky="e")

    label_29 = tk.Label(window, text="PET Drink(50cl)       N350", font="times 18")
    label_29.grid(row=12, column=1, sticky="e")

    label_30 = tk.Label(window, text="Glass/Canned Meat       N500", font="times 18")
    label_30.grid(row=13, column=1, sticky="e")

    label_31 = tk.Label(window, text="Fresh Yo       N600", font="times 18")
    label_31.grid(row=14, column=1, sticky="e")

    label_32 = tk.Label(window, text="Pineapple Juice       N350", font="times 18")
    label_32.grid(row=15, column=1, sticky="e")

    label_33 = tk.Label(window, text="Mango Juice       N350", font="times 18")
    label_33.grid(row=16, column=1, sticky="e")
    
    label_34 = tk.Label(window, text="Zobo Drink       N350", font="times 18")
    label_34.grid(row=17, column=1, sticky="e")

    label_35 = tk.Label(window, text="ENJOY!", font="times 28 bold")
    label_35.grid(sticky="ne")

def Billing_System():

    label_1 = tk.Label(root, text="CUSTOMER NOTICE(PLEASE NOTE THE FOLLOWING INFORMATION):")
    label_1.pack()
    label_2 = tk.Label(root, text="IF THE TOTAL ORDER IS LESS THAN N2500 CUSTOMER GETS A 10% DISCOUNT")
    label_2.pack()
    label_3 = tk.Label(root, text="IF THE TOTAL ORDER IS GREATER THAN N2500 AND LESS THAN N5000 CUSTOMER GETS A 15% DISCOUNT")
    label_3.pack()
    label_4 = tk.Label(root, text="IF THE TOTAL ORDER IS GREATER THAN N5000 CUSTOMER GETS A 25% DISCOUNT")
    label_4.pack()
    label_5 = tk.Label(root, text="IF THE TOTAL ORDER IS LESS THAN N1000 CUSTOMER RECEIVES ZERO DISCOUNT")
    label_5.pack()
    label_6 = tk.Label(root, text="YOU CAN ONLY ENTER ONE ITEM PER PURCHASE")
    label_6.pack()
    
    order = order_entry.get()
    name = name_entry.get()
    quantity = quantity_entry.get()

    if order not in menu_prices:
        messagebox.showerror("Error", "Invalid item entered")
        return

    if not quantity.isdigit() or int(quantity) <= 0:
        messagebox.showerror("Error", "Invalid quantity entered")
        return

    total_cost = menu_prices[order] * int(quantity)
    messagebox.showinfo("Total Cost", f"Total cost for {quantity} {order}(s): N{total_cost}")

    # Apply discounts based on total cost
    if total_cost < 2500:
        total_cost = total_cost - (total_cost * 0.1)  # 10% discount
    elif total_cost < 5000:
        total_cost = total_cost - (total_cost * 0.15)  # 15% discount
    else:
        total_cost = total_cost - (total_cost * 0.25)  # 25% discount

    messagebox.showinfo("Final Cost", f"The final cost after discount: N{total_cost}")

root = tk.Tk()
root.title("Cost/unit order box")
menu_display()

order_label = tk.Label(root, text="Enter the item you want to order:")
order_label.pack()
order_entry = tk.Entry(root)
order_entry.pack()

name_label = tk.Label(root, text="Enter your name:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

quantity_label = tk.Label(root, text="Enter quantity:")
quantity_label.pack()
quantity_entry = tk.Entry(root)
quantity_entry.pack()

submit_button = tk.Button(root, text="Submit", command=Billing_System)
submit_button.pack()

root.mainloop()
